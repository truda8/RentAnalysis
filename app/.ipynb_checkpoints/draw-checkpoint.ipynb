# %% [markdown]
# # 租房数据可视化

# %% [markdown]
# ## 导包

# %%
from pyg2plot import Plot
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## 房租整体的平均值、最大值、最小值

# %%
with open("../data/overall_rent.json", encoding="utf-8") as file:
    overall_rent = json.loads(file.read())

# %%
overall_rent
# Out:
# [{'data_type': 'max', 'value': 9500},
#  {'data_type': 'avg', 'value': 1693.24},
#  {'data_type': 'min', 'value': 200}]

# %%
column0 = Plot("Column")

column0.set_options({
  "height": 400,
  "data": overall_rent,
  "xField": "data_type",
  "yField": "value",
  "seriesField": 'data_type',
  "appendPadding": [0, 400, 0, 0],
  "xAxis": {
      "title": {
          "text": "统计类型"
      }
  },
  "yAxis": {
      "title": {
          "text": "房租"
      }
  },
})
# column0.render_notebook()
column0.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="dae0de8096a54c1db3f48bf483afbc46" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_dae0de8096a54c1db3f48bf483afbc46 = new G2Plot.Column("dae0de8096a54c1db3f48bf483afbc46", {
#   "height": 400,
#   "data": [
#     {
#       "data_type": "max",
#       "value": 9500
#     },
#     {
#       "data_type": "avg",
#       "value": 1693.24
#     },
#     {
#       "data_type": "min",
#       "value": 200
#     }
#   ],
#   "xField": "data_type",
#   "yField": "value",
#   "seriesField": "data_type",
#   "appendPadding": [
#     0,
#     600,
#     0,
#     0
#   ],
#   "xAxis": {
#     "title": {
#       "text": "\u7edf\u8ba1\u7c7b\u578b"
#     }
#   },
#   "yAxis": {
#     "title": {
#       "text": "\u623f\u79df"
#     }
#   }
# });
#       plot_dae0de8096a54c1db3f48bf483afbc46.render();
#     });
#   </script>
# </body>
# </html>

# %% [markdown]
# ## 各区租房数量柱形图

# %%
rentals_num = pd.read_csv("../data/rentals_num.csv")
# rentals_num = rentals_num.sort_values("counts", ascending=True)  # 排序
rentals_num.head()
# Out:
#   area  counts
# 0   柳城      11
# 1   融水     181
# 2   柳江     180
# 3   三江     177
# 4  鱼峰区      11

# %%
rentals_num_data = [{"area": area_name, "value": count} for area_name, count in zip(rentals_num["area"], rentals_num["counts"])]

# %%
column1 = Plot("Column")

column1.set_options({
  "height": 300,
  "data": rentals_num_data,
  "xField": "area",
  "yField": "value",
  "appendPadding": [0, 200, 0, 0],
  "xAxis": {
      "title": {
          "text": "区域"
      }
  },
  "yAxis": {
      "title": {
          "text": "租房数"
      }
  },
})
# column1.render_notebook()
column1.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="fdd971ce091846e49f325ada92c2c2b8" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_fdd971ce091846e49f325ada92c2c2b8 = new G2Plot.Column("fdd971ce091846e49f325ada92c2c2b8", {
#   "height": 300,
#   "data": [
#     {
#       "area": "\u67f3\u57ce",
#       "value": 11
#     },
#     {
#       "area": "\u878d\u6c34",
#       "value": 181
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "value": 180
#     },
#     {
#       "area": "\u4e09\u6c5f",
#       "value": 177
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "value": 11
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "value": 168
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "value": 22
#     },
#     {
#       "area": "\u9e7f\u5be8",
#       "value": 10
#     },
#     {
#       "area": "\u878d\u5b89",
#       "value": 163
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "value": 116
#     }
#   ],
#   "xField": "area",
#   "yField": "value",
#   "appendPadding": [
#     0,
#     200,
#     0,
#     0
#   ],
#   "xAxis": {
#     "title": {
#       "text": "\u533a\u57df"
#     }
#   },
#   "yAxis": {
#     "title": {
#       "text": "\u79df\u623f\u6570"
#     }
#   }
# });
#       plot_fdd971ce091846e49f325ada92c2c2b8.render();
#     });
#   </script>
# </body>
# </html>

# %% [markdown]
# ## 各个区房租的最大值、最小值、平均值、中位数对比

# %%
statistical_data = pd.read_csv("../data/statistical_data.csv")
statistical_data.head()
# Out:
#   area  min   max     mean  median
# 0   柳城  300  2000  1231.82    1000
# 1   融水  550  7999  2233.06    1200
# 2   柳江  350  9500  2027.60    1000
# 3   三江  200  4000  1552.87    1100
# 4  鱼峰区  250  1800   922.73    1800

# %%
statistical_data2 = []
for row in statistical_data.values:
    item_data1 = {"area": row[0], "value": row[1], "type": "min"}
    item_data2 = {"area": row[0], "value": row[2], "type": "max"}
    item_data3 = {"area": row[0], "value": row[3], "type": "mean"}
    item_data4 = {"area": row[0], "value": row[4], "type": "median"}
    statistical_data2.append(item_data1)
    statistical_data2.append(item_data2)
    statistical_data2.append(item_data3)
    statistical_data2.append(item_data4)

# %%
column2 = Plot("Column")

column2.set_options({
  "height": 300,
  "data": statistical_data2,
  "isStack": True,
  "xField": "area",
  "yField": "value",
  "seriesField": 'type',
  "isGroup": 'true',
  "appendPadding": [0, 0, 0, 0],
  "columnStyle": {
        "radius": [20, 20, 0, 0],
  },
  "xAxis": {
      "title": {
          "text": "区域"
      }
  },
  "yAxis": {
      "title": {
          "text": "房租"
      }
  },
})
# column2.render_notebook()
column2.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="6b2c35770fd740758ca65057927a9231" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_6b2c35770fd740758ca65057927a9231 = new G2Plot.Column("6b2c35770fd740758ca65057927a9231", {
#   "height": 300,
#   "data": [
#     {
#       "area": "\u67f3\u57ce",
#       "value": 300,
#       "type": "min"
#     },
#     {
#       "area": "\u67f3\u57ce",
#       "value": 2000,
#       "type": "max"
#     },
#     {
#       "area": "\u67f3\u57ce",
#       "value": 1231.82,
#       "type": "mean"
#     },
#     {
#       "area": "\u67f3\u57ce",
#       "value": 1000,
#       "type": "median"
#     },
#     {
#       "area": "\u878d\u6c34",
#       "value": 550,
#       "type": "min"
#     },
#     {
#       "area": "\u878d\u6c34",
#       "value": 7999,
#       "type": "max"
#     },
#     {
#       "area": "\u878d\u6c34",
#       "value": 2233.06,
#       "type": "mean"
#     },
#     {
#       "area": "\u878d\u6c34",
#       "value": 1200,
#       "type": "median"
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "value": 350,
#       "type": "min"
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "value": 9500,
#       "type": "max"
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "value": 2027.6,
#       "type": "mean"
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "value": 1000,
#       "type": "median"
#     },
#     {
#       "area": "\u4e09\u6c5f",
#       "value": 200,
#       "type": "min"
#     },
#     {
#       "area": "\u4e09\u6c5f",
#       "value": 4000,
#       "type": "max"
#     },
#     {
#       "area": "\u4e09\u6c5f",
#       "value": 1552.87,
#       "type": "mean"
#     },
#     {
#       "area": "\u4e09\u6c5f",
#       "value": 1100,
#       "type": "median"
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "value": 250,
#       "type": "min"
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "value": 1800,
#       "type": "max"
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "value": 922.73,
#       "type": "mean"
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "value": 1800,
#       "type": "median"
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "value": 300,
#       "type": "min"
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "value": 3800,
#       "type": "max"
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "value": 1052.55,
#       "type": "mean"
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "value": 1700,
#       "type": "median"
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "value": 300,
#       "type": "min"
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "value": 2500,
#       "type": "max"
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "value": 1195.45,
#       "type": "mean"
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "value": 2100,
#       "type": "median"
#     },
#     {
#       "area": "\u9e7f\u5be8",
#       "value": 300,
#       "type": "min"
#     },
#     {
#       "area": "\u9e7f\u5be8",
#       "value": 6000,
#       "type": "max"
#     },
#     {
#       "area": "\u9e7f\u5be8",
#       "value": 2470.0,
#       "type": "mean"
#     },
#     {
#       "area": "\u9e7f\u5be8",
#       "value": 1100,
#       "type": "median"
#     },
#     {
#       "area": "\u878d\u5b89",
#       "value": 330,
#       "type": "min"
#     },
#     {
#       "area": "\u878d\u5b89",
#       "value": 4000,
#       "type": "max"
#     },
#     {
#       "area": "\u878d\u5b89",
#       "value": 1821.07,
#       "type": "mean"
#     },
#     {
#       "area": "\u878d\u5b89",
#       "value": 1200,
#       "type": "median"
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "value": 300,
#       "type": "min"
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "value": 8888,
#       "type": "max"
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "value": 1438.78,
#       "type": "mean"
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "value": 1500,
#       "type": "median"
#     }
#   ],
#   "isStack": true,
#   "xField": "area",
#   "yField": "value",
#   "seriesField": "type",
#   "isGroup": "true",
#   "appendPadding": [
#     0,
#     0,
#     0,
#     0
#   ],
#   "columnStyle": {
#     "radius": [
#       20,
#       20,
#       0,
#       0
#     ]
#   },
#   "xAxis": {
#     "title": {
#       "text": "\u533a\u57df"
#     }
#   },
#   "yAxis": {
#     "title": {
#       "text": "\u623f\u79df"
#     }
#   }
# });
#       plot_6b2c35770fd740758ca65057927a9231.render();
#     });
#   </script>
# </body>
# </html>

# %% [markdown]
# ## 分类统计

# %% [markdown]
# 按租金：500元以下、500-800元、800-1200元、1200-1500元、1500-2000元、2000元以上
#
# 按面积：50m²以下、50-70m²、70-90m²、90-120m²、120-150m²、150m²以上

# %%
with open("../data/rent_counts.json", encoding="utf-8") as file:
    rent_counts = json.loads(file.read())
with open("../data/buildarea_counts.json", encoding="utf-8") as file:
    buildarea_counts = json.loads(file.read())

# %%
piePlot0 = Plot("Pie")

piePlot0.set_options({
  "height": 350,
  "data": rent_counts,
  "colorField": "rent",
  "angleField": "value",
  "radius": 1,
  "innerRadius": 0.6,
  "appendPadding": 10,
  "label": {
    "type": 'inner',
    "offset": '-50%',
    "content": '{value}',
    "style": {
      "textAlign": 'center',
      "fontSize": 18,
    },
  },
})
# piePlot0.render_notebook()
piePlot0.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="6ac708ea6d874ac6b064435e9c63d13a" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_6ac708ea6d874ac6b064435e9c63d13a = new G2Plot.Pie("6ac708ea6d874ac6b064435e9c63d13a", {
#   "height": 350,
#   "data": [
#     {
#       "rent": "500\u5143\u4ee5\u4e0b",
#       "value": 66
#     },
#     {
#       "rent": "500-800\u5143",
#       "value": 98
#     },
#     {
#       "rent": "800-1200\u5143",
#       "value": 162
#     },
#     {
#       "rent": "1200-1500\u5143",
#       "value": 142
#     },
#     {
#       "rent": "1500-2000\u5143",
#       "value": 237
#     },
#     {
#       "rent": "2000\u5143\u4ee5\u4e0a",
#       "value": 334
#     }
#   ],
#   "colorField": "rent",
#   "angleField": "value",
#   "radius": 1,
#   "innerRadius": 0.6,
#   "appendPadding": 10,
#   "label": {
#     "type": "inner",
#     "offset": "-50%",
#     "content": "{value}",
#     "style": {
#       "textAlign": "center",
#       "fontSize": 18
#     }
#   }
# });
#       plot_6ac708ea6d874ac6b064435e9c63d13a.render();
#     });
#   </script>
# </body>
# </html>

# %%
piePlot1 = Plot("Pie")

piePlot1.set_options({
  "height": 350,
  "data": buildarea_counts,
  "colorField": "buildarea",
  "angleField": "value",
  "radius": 1,
  "innerRadius": 0.6,
  "appendPadding": 10,
  "label": {
    "type": 'inner',
    "offset": '-50%',
    "content": '{value}',
    "style": {
      "textAlign": 'center',
      "fontSize": 18,
    },
  },
})
# piePlot1.render_notebook()
piePlot1.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="a4d88fee7809452c8bcf16d378911479" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_a4d88fee7809452c8bcf16d378911479 = new G2Plot.Pie("a4d88fee7809452c8bcf16d378911479", {
#   "height": 350,
#   "data": [
#     {
#       "buildarea": "50m\u00b2\u4ee5\u4e0b",
#       "value": 232
#     },
#     {
#       "buildarea": "50-70m\u00b2",
#       "value": 176
#     },
#     {
#       "buildarea": "70-80m\u00b2",
#       "value": 218
#     },
#     {
#       "buildarea": "90-120m\u00b2",
#       "value": 238
#     },
#     {
#       "buildarea": "120-144m\u00b2",
#       "value": 125
#     },
#     {
#       "buildarea": "150m\u00b2\u4ee5\u4e0a",
#       "value": 50
#     }
#   ],
#   "colorField": "buildarea",
#   "angleField": "value",
#   "radius": 1,
#   "innerRadius": 0.6,
#   "appendPadding": 10,
#   "label": {
#     "type": "inner",
#     "offset": "-50%",
#     "content": "{value}",
#     "style": {
#       "textAlign": "center",
#       "fontSize": 18
#     }
#   }
# });
#       plot_a4d88fee7809452c8bcf16d378911479.render();
#     });
#   </script>
# </body>
# </html>

# %%
rent_data = pd.read_csv("../data/rent.csv")
rent_data = rent_data.drop(columns=["address"])
rent_data = rent_data.values

# %%
rent_data_list = []
for row in rent_data:
    rent_item = {
        "area": row[0],
        "price": row[1],
        "buildarea": row[2]
    }
    rent_data_list.append(rent_item)

# %%
Scatter = Plot("Scatter")

Scatter.set_options({
    "height": 300,
    "data": rent_data_list,
    "xField": "buildarea",
    "yField": "price",
    "shape": "circle",
    "colorField": "area",
    "size": 4,
    "xAxis": {
      "title": {
          "text": "面积"
      }
    },
    "yAxis": {
      "title": {
          "text": "房租"
      }
    },
})
# Scatter.render_notebook()
Scatter.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="519910888c664ec3b693bb428e332077" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_519910888c664ec3b693bb428e332077 = new G2Plot.Scatter("519910888c664ec3b693bb428e332077", {
#   "height": 300,
#   "data": [
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2100,
#       "buildarea": 110.0
#     },
#     {
#       "area": "\u57ce\u4e2d\u533a",
#       "price": 2600,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 1250,
#       "buildarea": 85.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2000,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u67f3\u6c5f",
#       "price": 650,
#       "buildarea": 45.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 800,
#       "buildarea": 47.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1200,
#       "buildarea": 50.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2799,
#       "buildarea": 65.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 1550,
#       "buildarea": 68.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 700,
#       "buildarea": 120.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2300,
#       "buildarea": 119.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2000,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1500,
#       "buildarea": 103.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1000,
#       "buildarea": 82.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 600,
#       "buildarea": 72.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 350,
#       "buildarea": 20.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1200,
#       "buildarea": 108.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1800,
#       "buildarea": 88.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 3199,
#       "buildarea": 110.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1500,
#       "buildarea": 35.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1300,
#       "buildarea": 90.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1200,
#       "buildarea": 24.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 900,
#       "buildarea": 108.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1000,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 3200,
#       "buildarea": 110.34
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 800,
#       "buildarea": 30.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2600,
#       "buildarea": 87.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1100,
#       "buildarea": 60.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 1000,
#       "buildarea": 120.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2200,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1700,
#       "buildarea": 78.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1200,
#       "buildarea": 76.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 3300,
#       "buildarea": 70.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1500,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 4000,
#       "buildarea": 200.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 700,
#       "buildarea": 60.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 600,
#       "buildarea": 50.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 400,
#       "buildarea": 35.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 1500,
#       "buildarea": 70.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1200,
#       "buildarea": 60.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2000,
#       "buildarea": 85.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1600,
#       "buildarea": 120.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 550,
#       "buildarea": 55.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 700,
#       "buildarea": 14.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 800,
#       "buildarea": 36.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 2100,
#       "buildarea": 56.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 1950,
#       "buildarea": 106.5
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 3000,
#       "buildarea": 110.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 1700,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2300,
#       "buildarea": 95.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 1900,
#       "buildarea": 70.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 750,
#       "buildarea": 25.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 300,
#       "buildarea": 12.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 1980,
#       "buildarea": 40.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 800,
#       "buildarea": 30.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1500,
#       "buildarea": 90.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2400,
#       "buildarea": 80.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 2400,
#       "buildarea": 120.0
#     },
#     {
#       "area": "\u9c7c\u5cf0\u533a",
#       "price": 750,
#       "buildarea": 25.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1200,
#       "buildarea": 100.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 3800,
#       "buildarea": 140.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 1500,
#       "buildarea": 90.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1200,
#       "buildarea": 85.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1500,
#       "buildarea": 58.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 350,
#       "buildarea": 12.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1700,
#       "buildarea": 87.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1300,
#       "buildarea": 53.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 3200,
#       "buildarea": 170.0
#     },
#     {
#       "area": "\u878d\u5b89",
#       "price": 450,
#       "buildarea": 22.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 650,
#       "buildarea": 90.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 500,
#       "buildarea": 18.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 1300,
#       "buildarea": 70.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 600,
#       "buildarea": 18.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 2100,
#       "buildarea": 75.0
#     },
#     {
#       "area": "\u67f3\u5357\u533a",
#       "price": 500,
#       "buildarea": 35.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 1500,
#       "buildarea": 90.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
#       "price": 1500,
#       "buildarea": 118.0
#     },
#     {
#       "area": "\u67f3\u5317\u533a",
